# %%
import pandas as pd

# %%
pd.read_pickle('data_my/songs_tagged.pkl')
# Out:
#                                               title  \
# 0                                  смельчак и ветер
# 1                                проказник скоморох
# 2                                       верная жена
# 3                                          садовник
# 4                                     блуждают тени
# ..                                              ...
# 286  священник больше ничего не скажет (ария тодда)
# 287               небесный суд (дуэт судьи и тодда)
# 288                    почему ты жива? (ария тодда)
# 289                     смерть ловетт (ария ловетт)
# 290                  на краю (последняя ария тодда)
#
#                                                 lyrics  album_id  \
# 0    Припев:\n\nЯ ведь не из робких,\nВсе мне по пл...         0
# 1    На свадьбе скоморох,\nБыл прытким как горох.\n...         0
# 2    Дождливой ночью парень, выбравшись из леса\nВд...         0
# 3    Целый вечер нет покоя парню от его сестер:\n"Т...         0
# ...
